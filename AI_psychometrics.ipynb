# %% [markdown]
# # AI Psychometrics (D'Urso and Haslbeck, 2024)

# %% [markdown]
# # The following script is a pilot script for analysing the correlation between personality scores obtained through open-source llm via zero-shot classification and real data.

# %% [markdown]
# ## Step 1: Translating the english survey questions in the following languages:
#
# - Chinese
# - Italian

# %%
import pandas as pd 
import numpy as np

# %%
questions = ["I am the life of the party.",
              "I don't talk a lot.",
              "I feel comfortable around people.",
              "I keep in the background.",
              "I start conversations.",
              "I have little to say.",
              "I talk to a lot of different people at parties.",
              "I don't like to draw attention to myself.",
              "I don't mind being the center of attention.",
              "I am quiet around strangers.",
              "I get stressed out easily.",
              "I am relaxed most of the time.",
              "I worry about things.",
              "I seldom feel blue.",
              "I am easily disturbed.",
              "I get upset easily.",
              "I change my mood a lot.",
              "I have frequent mood swings.",
              "I get irritated easily.",
              "I often feel blue.",
              "I feel little concern for others.",
              "I am interested in people.",
              "I insult people.",
              "I sympathize with others' feelings.",
              "I am not interested in other people's problems.",
              "I have a soft heart.",
              "I am not really interested in others.",
              "I take time out for others.",
              "I feel others' emotions.",
              "I make people feel at ease.",
              "I am always prepared.",
              "I leave my belongings around.",
              "I pay attention to details.",
              "I make a mess of things.",
              "I get chores done right away.",
              "I often forget to put things back in their proper place.",
              "I like order.",
              "I shirk my duties.",
              "I follow a schedule.",
              "I am exacting in my work.",
              "I have a rich vocabulary.",
              "I have difficulty understanding abstract ideas.",
              "I have a vivid imagination.",
              "I am not interested in abstract ideas.",
              "I have excellent ideas.",
              "I do not have a good imagination.",
              "I am quick to understand things.",
              "I use difficult words.",
              "I spend time reflecting on things.",
              "I am full of ideas." ]

labels_questions = ["EXT1"	,
                    "EXT2"	,
                    "EXT3"	,
                    "EXT4"	,
                    "EXT5"	,
                    "EXT6"	,
                    "EXT7"	,
                    "EXT8"	,
                    "EXT9"	,
                    "EXT10",
                    "EST1"	,
                    "EST2"	,
                    "EST3"	,
                    "EST4"	,
                    "EST5"	,
                    "EST6"	,
                    "EST7"	,
                    "EST8"	,
                    "EST9"	,
                    "EST10",
                    "AGR1"	,
                    "AGR2"	,
                    "AGR3"	,
                    "AGR4"	,
                    "AGR5"	,
                    "AGR6"	,
                    "AGR7"	,
                    "AGR8"	,
                    "AGR9"	,
                    "AGR10",
                    "CSN1"	,
                    "CSN2"	,
                    "CSN3"	,
                    "CSN4"	,
                    "CSN5"	,
                    "CSN6"	,
                    "CSN7"	,
                    "CSN8"	,
                    "CSN9"	,
                    "CSN10",
                    "OPN1"	,
                    "OPN2"	,
                    "OPN3"	,
                    "OPN4"	,
                    "OPN5"	,
                    "OPN6"	,
                    "OPN7"	,
                    "OPN8"	,
                    "OPN9"	,
                    "OPN10"]

big5_qs = pd.DataFrame(list(zip(labels_questions, questions)), columns = ['item', 'question'])

# %%
# response options (for now we use default from https://github.com/Alheimsins/b5-johnson-120-ipip-neo-pi-r) but we may consider translating
languages = ['en', 'it', 'zh']

# Response options below. Copied from the .js files in the different language folders

candidate_labels_en = [
    "Very Inaccurate",
    "Moderately Inaccurate",
    "Neither Accurate Nor Inaccurate",
    "Moderately Accurate",
    "Very Accurate",
]
candidate_labels_it = [
    "Molto in disaccordo",
    " In disaccordo",
    "Nè in accordo nè in disaccordo",
    "In accordo",
    " Molto in accordo",
]
candidate_labels_ch = ["错误", "失准", "普通", "准确", "精确"]

labels = pd.DataFrame(
    list(
        zip(
            candidate_labels_en,
            candidate_labels_it,
            candidate_labels_ch
        )
    ),
    columns=languages,
)
labels
# Out:
#                                 en                              it  zh
# 0                  Very Inaccurate             Molto in disaccordo  错误
# 1            Moderately Inaccurate                   In disaccordo  失准
# 2  Neither Accurate Nor Inaccurate  Nè in accordo nè in disaccordo  普通
# 3              Moderately Accurate                      In accordo  准确
# 4                    Very Accurate                Molto in accordo  精确

# %%
#call translation package and translate questions
import translators as ts

translators_services = ['google', 'bing', 'baidu'] #translation services 
languages = ['it', 'zh'] #languages to translate the questions to 

#for loop to translate across different translation services, languages and add as columns to the original data set
for serv in translators_services:
    for lang in languages:
        temp = []
        for item in big5_qs['question']:
            temp.append(ts.translate_text(item, from_language='en', to_language=lang, translator=serv)) #from language is necessary because some translators (e.g., alibaba) default to origin country setting "china".
        big5_qs = pd.concat([big5_qs, pd.DataFrame(list(zip(temp)),columns =[lang + '_' + serv])], axis = 1)

# %%
big5_qs.head()
# Out:
#    item                           question  \
# 0  EXT1        I am the life of the party.
# 1  EXT2                I don't talk a lot.
# 2  EXT3  I feel comfortable around people.
# 3  EXT4          I keep in the background.
# 4  EXT5             I start conversations.
#
#                              it_google zh_google  \
# 0            Sono la vita della festa.  我是聚会的生活。
# 1                     Non parlo molto.    我说话不多。
# 2  Mi sento a mio agio con le persone.   我周围很舒服。
# 3                 Tengo in background.    我留在后台。
# 4             Inizio le conversazioni.    我开始对话。
#
#                                it_bing       zh_bing  \
# 0         Io sono l'anima della festa.       我是党的生命。
# 1                     Non parlo molto.       我不怎么说话。
# 2  Mi sento a mio agio con le persone.  我和人在一起感觉很舒服。
# 3                Rimango sullo sfondo.       我保持在后台。
# 4             Inizio le conversazioni.        我开始对话。
#
#                             it_baidu      zh_baidu
# 0       Io sono la vita della festa.       我是党的生命。
# 1                   Non parlo molto.       我不怎么说话。
# 2  Mi sento a mio agio con la gente.  和人在一起我感觉很舒服。
# 3             Mi tengo sullo sfondo.       我一直在幕后。
# 4              Inizio conversazioni.        我开始交谈。

# %% [markdown]
# ## Step 2: Let llm respond to questions in different languages

# %%
from transformers import pipeline

# %%
responses = []
languages = ['en', 'it', 'zh', 'it', 'zh', 'it', 'zh']

for item in range(0,len(languages)):
    classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
    answerlist = list(labels[languages[item]])
    questionlist = big5_qs.iloc[:,item+1]
    for sequence_to_classify_english in questionlist:
        answer = classifier(sequence_to_classify_english, answerlist)
        print(answer)
        responses.append(answer)
# Out:
# {'sequence': 'I am the life of the party.', 'labels': ['Moderately Accurate', 'Very Accurate', 'Moderately Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.40380170941352844, 0.3170546293258667, 0.18389591574668884, 0.06463424116373062, 0.03061349131166935]}
# {'sequence': "I don't talk a lot.", 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.6016448736190796, 0.29415029287338257, 0.04612812027335167, 0.03574517369270325, 0.022331498563289642]}
# {'sequence': 'I feel comfortable around people.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.6052239537239075, 0.21031251549720764, 0.12311545014381409, 0.03462200239300728, 0.02672610990703106]}
# {'sequence': 'I keep in the background.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.5883980393409729, 0.28178009390830994, 0.05187308043241501, 0.04012250527739525, 0.03782627731561661]}
# {'sequence': 'I start conversations.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.5384691953659058, 0.25353091955184937, 0.1195082888007164, 0.04457657411694527, 0.04391508176922798]}
# {'sequence': 'I have little to say.', 'labels': ['Moderately Inaccurate', 'Moderately Accurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate', 'Very Accurate'], 'scores': [0.4340602457523346, 0.4089639186859131, 0.09229777753353119, 0.05593454837799072, 0.008743472397327423]}
# {'sequence': 'I talk to a lot of different people at parties.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.4416106939315796, 0.330028772354126, 0.11661835759878159, 0.06383795291185379, 0.04790418967604637]}
# {'sequence': "I don't like to draw attention to myself.", 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Accurate'], 'scores': [0.5698679685592651, 0.30532780289649963, 0.055991511791944504, 0.03954044356942177, 0.02927229553461075]}
# {'sequence': "I don't mind being the center of attention.", 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.5403980016708374, 0.22384798526763916, 0.17761483788490295, 0.031484734266996384, 0.02665444277226925]}
# {'sequence': 'I am quiet around strangers.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.5592008829116821, 0.3115415573120117, 0.05029509216547012, 0.04583900049328804, 0.03312349319458008]}
# {'sequence': 'I get stressed out easily.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.43689781427383423, 0.3632757067680359, 0.1040402501821518, 0.06927760690450668, 0.026508674025535583]}
# {'sequence': 'I am relaxed most of the time.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.6870514154434204, 0.2073027491569519, 0.053747646510601044, 0.026823030784726143, 0.025075066834688187]}
# {'sequence': 'I worry about things.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.46528753638267517, 0.3587113618850708, 0.07124709337949753, 0.06524870544672012, 0.039505407214164734]}
# {'sequence': 'I seldom feel blue.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate', 'Very Accurate'], 'scores': [0.5248401761054993, 0.32194000482559204, 0.06022367253899574, 0.050975359976291656, 0.0420207642018795]}
# {'sequence': 'I am easily disturbed.', 'labels': ['Moderately Inaccurate', 'Moderately Accurate', 'Very Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.5123245716094971, 0.2734066843986511, 0.1474708616733551, 0.037033822387456894, 0.029764004051685333]}
# {'sequence': 'I get upset easily.', 'labels': ['Moderately Inaccurate', 'Moderately Accurate', 'Very Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.4506344199180603, 0.3733082711696625, 0.1064252033829689, 0.04324262589216232, 0.026389479637145996]}
# {'sequence': 'I change my mood a lot.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.4413648247718811, 0.3486535847187042, 0.09514955431222916, 0.079635851085186, 0.0351962149143219]}
# {'sequence': 'I have frequent mood swings.', 'labels': ['Moderately Inaccurate', 'Moderately Accurate', 'Very Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.415500283241272, 0.39481931924819946, 0.07938720285892487, 0.06766679883003235, 0.04262646660208702]}
# {'sequence': 'I get irritated easily.', 'labels': ['Moderately Inaccurate', 'Moderately Accurate', 'Very Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.42124301195144653, 0.41540953516960144, 0.08219625800848007, 0.05105912685394287, 0.030092038214206696]}
# {'sequence': 'I often feel blue.', 'labels': ['Moderately Inaccurate', 'Moderately Accurate', 'Very Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.4998922646045685, 0.3573817312717438, 0.07594938576221466, 0.04101303964853287, 0.02576359361410141]}
# {'sequence': 'I feel little concern for others.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Accurate'], 'scores': [0.4896814227104187, 0.35136258602142334, 0.07529193162918091, 0.05804974585771561, 0.025614261627197266]}
# {'sequence': 'I am interested in people.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.5219206809997559, 0.28060367703437805, 0.1132265105843544, 0.04517390951514244, 0.03907526284456253]}
# {'sequence': 'I insult people.', 'labels': ['Moderately Inaccurate', 'Very Inaccurate', 'Moderately Accurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.45714256167411804, 0.36525726318359375, 0.12633712589740753, 0.03058934397995472, 0.020673753693699837]}
# {'sequence': "I sympathize with others' feelings.", 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.541581928730011, 0.28073850274086, 0.11245636641979218, 0.038641076534986496, 0.02658209577202797]}
# {'sequence': "I am not interested in other people's problems.", 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Accurate'], 'scores': [0.42223358154296875, 0.3945131003856659, 0.0976465567946434, 0.062325846403837204, 0.023280935361981392]}
# {'sequence': 'I have a soft heart.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.49849870800971985, 0.29295673966407776, 0.12005318701267242, 0.0462506078183651, 0.042240820825099945]}
# {'sequence': 'I am not really interested in others.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Accurate'], 'scores': [0.4754270315170288, 0.3699144721031189, 0.07821348309516907, 0.051712632179260254, 0.02473231963813305]}
# {'sequence': 'I take time out for others.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.48946020007133484, 0.2816096246242523, 0.13560456037521362, 0.05252434313297272, 0.04080130159854889]}
# {'sequence': "I feel others' emotions.", 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.42465853691101074, 0.25018343329429626, 0.24887004494667053, 0.04145536199212074, 0.034832604229450226]}
# {'sequence': 'I make people feel at ease.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.5966384410858154, 0.2001098394393921, 0.13618530333042145, 0.037287387996912, 0.02977898344397545]}
# {'sequence': 'I am always prepared.', 'labels': ['Moderately Accurate', 'Very Accurate', 'Moderately Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.45642104744911194, 0.3090569078922272, 0.15548492968082428, 0.05757052078843117, 0.021466584876179695]}
# {'sequence': 'I leave my belongings around.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.4700451195240021, 0.31024688482284546, 0.11179666221141815, 0.05899575725197792, 0.04891560226678848]}
# {'sequence': 'I pay attention to details.', 'labels': ['Moderately Accurate', 'Very Accurate', 'Moderately Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.4869050681591034, 0.2604962885379791, 0.18071551620960236, 0.04497369006276131, 0.026909461244940758]}
# {'sequence': 'I make a mess of things.', 'labels': ['Moderately Inaccurate', 'Very Inaccurate', 'Moderately Accurate', 'Neither Accurate Nor Inaccurate', 'Very Accurate'], 'scores': [0.6228212714195251, 0.2266453057527542, 0.10901334881782532, 0.03088645078241825, 0.010633724741637707]}
# {'sequence': 'I get chores done right away.', 'labels': ['Moderately Accurate', 'Very Accurate', 'Moderately Inaccurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.4486313462257385, 0.25267302989959717, 0.2254655957221985, 0.03842470422387123, 0.03480532020330429]}
# {'sequence': 'I often forget to put things back in their proper place.', 'labels': ['Moderately Inaccurate', 'Moderately Accurate', 'Very Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.47383326292037964, 0.2973055839538574, 0.15690301358699799, 0.04025442898273468, 0.031703706830739975]}
# {'sequence': 'I like order.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.6777380704879761, 0.13434913754463196, 0.11399459093809128, 0.05591155216097832, 0.018006619065999985]}
# {'sequence': 'I shirk my duties.', 'labels': ['Moderately Inaccurate', 'Very Inaccurate', 'Moderately Accurate', 'Neither Accurate Nor Inaccurate', 'Very Accurate'], 'scores': [0.6136272549629211, 0.20311377942562103, 0.12694287300109863, 0.0384661890566349, 0.017849890515208244]}
# {'sequence': 'I follow a schedule.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.70843106508255, 0.13378658890724182, 0.09321865439414978, 0.044039033353328705, 0.020524676889181137]}
# {'sequence': 'I am exacting in my work.', 'labels': ['Very Accurate', 'Moderately Accurate', 'Moderately Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.79557865858078, 0.07954107969999313, 0.06897848844528198, 0.04045436158776283, 0.015447405166924]}
# {'sequence': 'I have a rich vocabulary.', 'labels': ['Moderately Accurate', 'Very Accurate', 'Moderately Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.40253666043281555, 0.3607653081417084, 0.13445037603378296, 0.08004669845104218, 0.022200968116521835]}
# {'sequence': 'I have difficulty understanding abstract ideas.', 'labels': ['Moderately Inaccurate', 'Moderately Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Accurate'], 'scores': [0.6283838748931885, 0.17684103548526764, 0.14310580492019653, 0.04158853739500046, 0.010080779902637005]}
# {'sequence': 'I have a vivid imagination.', 'labels': ['Moderately Inaccurate', 'Moderately Accurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate', 'Very Accurate'], 'scores': [0.4162086546421051, 0.30949801206588745, 0.14607395231723785, 0.07301141321659088, 0.05520794913172722]}
# {'sequence': 'I am not interested in abstract ideas.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Accurate'], 'scores': [0.3919011950492859, 0.3880627453327179, 0.12638726830482483, 0.07598316669464111, 0.017665596678853035]}
# {'sequence': 'I have excellent ideas.', 'labels': ['Very Accurate', 'Moderately Accurate', 'Neither Accurate Nor Inaccurate', 'Moderately Inaccurate', 'Very Inaccurate'], 'scores': [0.36976972222328186, 0.36423179507255554, 0.1258460283279419, 0.11931677907705307, 0.020835649222135544]}
# {'sequence': 'I do not have a good imagination.', 'labels': ['Moderately Inaccurate', 'Moderately Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Accurate'], 'scores': [0.4960009455680847, 0.2530740797519684, 0.18902306258678436, 0.03860749676823616, 0.023294420912861824]}
# {'sequence': 'I am quick to understand things.', 'labels': ['Moderately Accurate', 'Very Accurate', 'Moderately Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Inaccurate'], 'scores': [0.5097460746765137, 0.30612391233444214, 0.10070966929197311, 0.06426706165075302, 0.01915327087044716]}
# {'sequence': 'I use difficult words.', 'labels': ['Moderately Inaccurate', 'Very Inaccurate', 'Moderately Accurate', 'Neither Accurate Nor Inaccurate', 'Very Accurate'], 'scores': [0.6102257966995239, 0.16549062728881836, 0.13222263753414154, 0.061719197779893875, 0.030341684818267822]}
# {'sequence': 'I spend time reflecting on things.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Very Accurate', 'Very Inaccurate', 'Neither Accurate Nor Inaccurate'], 'scores': [0.520738422870636, 0.2741835415363312, 0.10578323155641556, 0.049853306263685226, 0.04944153130054474]}
# {'sequence': 'I am full of ideas.', 'labels': ['Moderately Accurate', 'Moderately Inaccurate', 'Neither Accurate Nor Inaccurate', 'Very Accurate', 'Very Inaccurate'], 'scores': [0.46560999751091003, 0.3262068033218384, 0.08992104977369308, 0.06853771954774857, 0.049724504351615906]}
# {'sequence': 'Sono la vita della festa.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.710383951663971, 0.10913170129060745, 0.08346225321292877, 0.06523415446281433, 0.0317879356443882]}
# {'sequence': 'Non parlo molto.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.4942026436328888, 0.30513709783554077, 0.16867317259311676, 0.02226114645600319, 0.00972594041377306]}
# {'sequence': 'Mi sento a mio agio con le persone.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.46362486481666565, 0.3925119638442993, 0.11531570553779602, 0.01576431281864643, 0.012783169746398926]}
# {'sequence': 'Tengo in background.', 'labels': [' In disaccordo', 'In accordo', ' Molto in accordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.34396281838417053, 0.2666324973106384, 0.1307261437177658, 0.12980924546718597, 0.12886931002140045]}
# {'sequence': 'Inizio le conversazioni.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.6219266057014465, 0.13401764631271362, 0.11248239874839783, 0.08284325152635574, 0.048730093985795975]}
# {'sequence': 'Ho poco da dire.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.6017105579376221, 0.22686037421226501, 0.07440639287233353, 0.0727928876876831, 0.024229710921645164]}
# {'sequence': 'Parlo con molte persone diverse alle feste.', 'labels': ['Molto in disaccordo', ' Molto in accordo', 'In accordo', ' In disaccordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.34327852725982666, 0.32719770073890686, 0.12737460434436798, 0.12490972876548767, 0.07723946869373322]}
# {'sequence': "Non mi piace attirare l'attenzione su di me.", 'labels': [' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.5272915363311768, 0.38583746552467346, 0.06475873291492462, 0.016839785501360893, 0.005272530019283295]}
# {'sequence': "Non mi dispiace essere al centro dell'attenzione.", 'labels': [' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.6741030216217041, 0.2177702784538269, 0.09763132780790329, 0.006199430674314499, 0.004295891150832176]}
# {'sequence': 'Sono tranquillo con gli estranei.', 'labels': [' Molto in accordo', 'In accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.35962986946105957, 0.3062518537044525, 0.15828226506710052, 0.10984288901090622, 0.06599317491054535]}
# {'sequence': 'Mi sono stressato facilmente.', 'labels': [' Molto in accordo', 'In accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.38655728101730347, 0.2709120810031891, 0.14820702373981476, 0.09748799353837967, 0.09683553874492645]}
# {'sequence': 'Sono rilassato per la maggior parte del tempo.', 'labels': [' In disaccordo', ' Molto in accordo', 'In accordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.24532826244831085, 0.2147308886051178, 0.21106283366680145, 0.17101958394050598, 0.1578584462404251]}
# {'sequence': 'Mi preoccupo delle cose.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'In accordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo'], 'scores': [0.24197696149349213, 0.22446271777153015, 0.1985437273979187, 0.17904192209243774, 0.15597471594810486]}
# {'sequence': 'Raramente mi sento blu.', 'labels': [' In disaccordo', 'Molto in disaccordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'In accordo'], 'scores': [0.7498820424079895, 0.08090318739414215, 0.06819158047437668, 0.05091855302453041, 0.050104621797800064]}
# {'sequence': 'Sono facilmente disturbato.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.5538724660873413, 0.36039555072784424, 0.06175364926457405, 0.012276546098291874, 0.011701698414981365]}
# {'sequence': 'Mi arrabbio facilmente.', 'labels': ['In accordo', ' Molto in accordo', ' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.3925413191318512, 0.3041117191314697, 0.11935745179653168, 0.09591377526521683, 0.08807570487260818]}
# {'sequence': 'Cambio molto il mio umore.', 'labels': ['Molto in disaccordo', ' In disaccordo', ' Molto in accordo', 'In accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.33871668577194214, 0.2472211867570877, 0.24557548761367798, 0.1255408376455307, 0.042945828288793564]}
# {'sequence': "Ho frequenti sbalzi d'umore.", 'labels': ['Molto in disaccordo', ' In disaccordo', 'In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.31232866644859314, 0.2517797350883484, 0.15689899027347565, 0.14659668505191803, 0.1323959082365036]}
# {'sequence': 'Mi irrito facilmente.', 'labels': ['Molto in disaccordo', ' In disaccordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', 'In accordo'], 'scores': [0.44589534401893616, 0.4446953237056732, 0.050486139953136444, 0.03574097529053688, 0.02318226359784603]}
# {'sequence': 'Mi sento spesso blu.', 'labels': ['In accordo', ' Molto in accordo', ' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo'], 'scores': [0.3452885150909424, 0.3120734989643097, 0.14705950021743774, 0.1358857899904251, 0.05969270318746567]}
# {'sequence': 'Sento poca preoccupazione per gli altri.', 'labels': [' In disaccordo', 'In accordo', ' Molto in accordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.33463460206985474, 0.22645263373851776, 0.17319808900356293, 0.13595730066299438, 0.1297573447227478]}
# {'sequence': 'Sono interessato alle persone.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.455224871635437, 0.255440890789032, 0.1853266805410385, 0.06276413798332214, 0.04124341532588005]}
# {'sequence': 'Insulto le persone.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', 'In accordo'], 'scores': [0.7208367586135864, 0.2141423225402832, 0.05420000106096268, 0.005735883489251137, 0.005084857810288668]}
# {'sequence': 'Sono solidale con i sentimenti degli altri.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.6358149647712708, 0.34065985679626465, 0.0181831493973732, 0.002990532200783491, 0.002351464005187154]}
# {'sequence': 'Non sono interessato ai problemi di altre persone.', 'labels': [' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.5728838443756104, 0.23128198087215424, 0.11387280374765396, 0.04831944778561592, 0.0336420014500618]}
# {'sequence': 'Ho un cuore morbido.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', 'In accordo'], 'scores': [0.49275416135787964, 0.39404499530792236, 0.06961659342050552, 0.030135439708828926, 0.013448779471218586]}
# {'sequence': 'Non sono molto interessato agli altri.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.45348620414733887, 0.4396764934062958, 0.058067820966243744, 0.030948609113693237, 0.01782088913023472]}
# {'sequence': 'Mi prendo del tempo per gli altri.', 'labels': ['In accordo', ' Molto in accordo', ' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.4056045413017273, 0.24277161061763763, 0.180507630109787, 0.0882432758808136, 0.08287297189235687]}
# {'sequence': 'Sento le emozioni degli altri.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.4348304867744446, 0.1986566185951233, 0.18358628451824188, 0.10378198325634003, 0.07914461195468903]}
# {'sequence': 'Faccio sentire le persone a proprio agio.', 'labels': [' In disaccordo', 'In accordo', 'Molto in disaccordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.46197310090065, 0.2301628291606903, 0.10342042148113251, 0.10249493271112442, 0.10194867104291916]}
# {'sequence': 'Sono sempre preparato.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.47840097546577454, 0.2545042634010315, 0.17090816795825958, 0.060995008796453476, 0.035191603004932404]}
# {'sequence': 'Lascio le mie cose in giro.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.4502500295639038, 0.23473908007144928, 0.17281436920166016, 0.07870718091726303, 0.06348931789398193]}
# {'sequence': 'Prendo attenzione ai dettagli.', 'labels': ['In accordo', ' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' Molto in accordo'], 'scores': [0.2758888602256775, 0.2652825713157654, 0.18864065408706665, 0.14022527635097504, 0.12996266782283783]}
# {'sequence': 'Faccio un casino di cose.', 'labels': [' In disaccordo', 'In accordo', 'Molto in disaccordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.3662227988243103, 0.25599294900894165, 0.14105293154716492, 0.11900191009044647, 0.11772942543029785]}
# {'sequence': 'Faccio le faccende fatte subito.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', 'In accordo'], 'scores': [0.5796443223953247, 0.2445693016052246, 0.08676913380622864, 0.04458670690655708, 0.04443048685789108]}
# {'sequence': 'Spesso dimentico di rimettere le cose nel loro posto giusto.', 'labels': [' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.5418387651443481, 0.18284474313259125, 0.12273988872766495, 0.09530425071716309, 0.0572722963988781]}
# {'sequence': "Mi piace l'ordine.", 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.5663519501686096, 0.22223126888275146, 0.08704997599124908, 0.06902651488780975, 0.05534033477306366]}
# {'sequence': 'Spolgo i miei doveri.', 'labels': ['In accordo', ' Molto in accordo', ' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo'], 'scores': [0.3854343295097351, 0.359567791223526, 0.09413683414459229, 0.0922580286860466, 0.06860294938087463]}
# {'sequence': 'Seguo un programma.', 'labels': ['In accordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.5449979305267334, 0.18090280890464783, 0.17057792842388153, 0.05995415151119232, 0.043567147105932236]}
# {'sequence': 'Sto esaurendo il mio lavoro.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.6101820468902588, 0.314531147480011, 0.047285985201597214, 0.01699257269501686, 0.011008254252374172]}
# {'sequence': 'Ho un vocabolario ricco.', 'labels': [' Molto in accordo', 'In accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.3453029990196228, 0.2882749140262604, 0.13891752064228058, 0.13571108877658844, 0.0917934775352478]}
# {'sequence': 'Ho difficoltà a capire le idee astratte.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.7664486169815063, 0.13950300216674805, 0.07693009823560715, 0.010188009589910507, 0.006930284667760134]}
# {'sequence': 'Ho una vivida immaginazione.', 'labels': ['In accordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.4234945774078369, 0.23822906613349915, 0.1869392991065979, 0.0900765061378479, 0.06126050278544426]}
# {'sequence': 'Non sono interessato a idee astratte.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.6835896968841553, 0.19055019319057465, 0.09784935414791107, 0.0152773791924119, 0.012733416631817818]}
# {'sequence': 'Ho idee eccellenti.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.5757582783699036, 0.29585331678390503, 0.07881810516119003, 0.026369154453277588, 0.023201193660497665]}
# {'sequence': 'Non ho una buona immaginazione.', 'labels': [' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.6805993318557739, 0.19148632884025574, 0.10120736807584763, 0.017744850367307663, 0.008962109684944153]}
# {'sequence': 'Sono pronto a capire le cose.', 'labels': [' In disaccordo', 'In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo'], 'scores': [0.301798015832901, 0.2410147488117218, 0.15935440361499786, 0.15730121731758118, 0.14053162932395935]}
# {'sequence': 'Uso parole difficili.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.6508982181549072, 0.17428147792816162, 0.10578126460313797, 0.041971683502197266, 0.027067314833402634]}
# {'sequence': 'Trascorro del tempo a riflettere sulle cose.', 'labels': [' In disaccordo', 'In accordo', 'Molto in disaccordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.2769596576690674, 0.2641119956970215, 0.17123734951019287, 0.16640114784240723, 0.1212899312376976]}
# {'sequence': 'Sono pieno di idee.', 'labels': ['In accordo', ' Molto in accordo', ' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo'], 'scores': [0.40350744128227234, 0.250905305147171, 0.12902358174324036, 0.12462926656007767, 0.09193448722362518]}
# {'sequence': '我是聚会的生活。', 'labels': ['精确', '错误', '普通', '准确', '失准'], 'scores': [0.24143829941749573, 0.21807657182216644, 0.2145208865404129, 0.19545508921146393, 0.1305091381072998]}
# {'sequence': '我说话不多。', 'labels': ['错误', '准确', '普通', '精确', '失准'], 'scores': [0.2777448296546936, 0.2010602056980133, 0.19904181361198425, 0.1735992431640625, 0.1485539674758911]}
# {'sequence': '我周围很舒服。', 'labels': ['错误', '准确', '精确', '普通', '失准'], 'scores': [0.2310943752527237, 0.22417478263378143, 0.2192554920911789, 0.19096891582012177, 0.1345064640045166]}
# {'sequence': '我留在后台。', 'labels': ['错误', '精确', '准确', '普通', '失准'], 'scores': [0.2652955651283264, 0.21288646757602692, 0.20039337873458862, 0.18927142024040222, 0.13215315341949463]}
# {'sequence': '我开始对话。', 'labels': ['错误', '精确', '准确', '普通', '失准'], 'scores': [0.24071326851844788, 0.2285657525062561, 0.21518291532993317, 0.17498798668384552, 0.14055006206035614]}
# {'sequence': '我无话可说。', 'labels': ['错误', '准确', '精确', '普通', '失准'], 'scores': [0.2750331461429596, 0.2154589295387268, 0.19791190326213837, 0.19312100112438202, 0.11847499758005142]}
# {'sequence': '我在聚会上与许多不同的人交谈。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.22979457676410675, 0.2141251415014267, 0.1926644742488861, 0.18851634860038757, 0.17489945888519287]}
# {'sequence': '我不喜欢引起自己的注意。', 'labels': ['准确', '精确', '错误', '普通', '失准'], 'scores': [0.24663682281970978, 0.21777024865150452, 0.19464819133281708, 0.18812739849090576, 0.15281733870506287]}
# {'sequence': '我不介意成为关注的焦点。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.23079153895378113, 0.2153625637292862, 0.2067786008119583, 0.1929989904165268, 0.15406832098960876]}
# {'sequence': '我周围很安静。', 'labels': ['错误', '精确', '准确', '普通', '失准'], 'scores': [0.4499349296092987, 0.16667607426643372, 0.1608869731426239, 0.1370951384305954, 0.08540686219930649]}
# {'sequence': '我很容易感到压力。', 'labels': ['精确', '准确', '失准', '普通', '错误'], 'scores': [0.2986891269683838, 0.25275719165802, 0.1549832969903946, 0.15220023691654205, 0.14137016236782074]}
# {'sequence': '我大部分时间都很放松。', 'labels': ['精确', '错误', '准确', '普通', '失准'], 'scores': [0.2512173056602478, 0.24123230576515198, 0.22029012441635132, 0.15891897678375244, 0.12834125757217407]}
# {'sequence': '我担心事情。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.23771584033966064, 0.23565293848514557, 0.19388557970523834, 0.17269116640090942, 0.16005444526672363]}
# {'sequence': '我很少感到蓝色。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.2992044985294342, 0.23024889826774597, 0.2024676501750946, 0.1359892189502716, 0.13208967447280884]}
# {'sequence': '我很容易被打扰。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.28033775091171265, 0.20454970002174377, 0.19786006212234497, 0.1727028340101242, 0.14454962313175201]}
# {'sequence': '我很容易感到沮丧。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.2999798357486725, 0.2673413157463074, 0.16850468516349792, 0.14258556067943573, 0.1215885654091835]}
# {'sequence': '我经常改变心情。', 'labels': ['精确', '错误', '准确', '普通', '失准'], 'scores': [0.23885877430438995, 0.22238418459892273, 0.2183668613433838, 0.17659133672714233, 0.14379878342151642]}
# {'sequence': '我的心情经常波动。', 'labels': ['精确', '准确', '失准', '普通', '错误'], 'scores': [0.2589108645915985, 0.22892388701438904, 0.17362576723098755, 0.17118342220783234, 0.16735605895519257]}
# {'sequence': '我很容易发怒。', 'labels': ['精确', '准确', '错误', '失准', '普通'], 'scores': [0.26075875759124756, 0.20649899542331696, 0.20540061593055725, 0.1749182492494583, 0.1524234265089035]}
# {'sequence': '我经常感到蓝色。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.30258750915527344, 0.2465563267469406, 0.1693076342344284, 0.15242747962474823, 0.12912112474441528]}
# {'sequence': '我对别人几乎没有关注。', 'labels': ['精确', '准确', '普通', '失准', '错误'], 'scores': [0.317539781332016, 0.2654613256454468, 0.1761741042137146, 0.12347319722175598, 0.11735157668590546]}
# {'sequence': '我对人感兴趣。', 'labels': ['精确', '错误', '准确', '普通', '失准'], 'scores': [0.26874762773513794, 0.22439484298229218, 0.21203865110874176, 0.15817396342754364, 0.13664492964744568]}
# {'sequence': '我侮辱人。', 'labels': ['精确', '准确', '普通', '失准', '错误'], 'scores': [0.24886499345302582, 0.24219617247581482, 0.1977500319480896, 0.15813130140304565, 0.1530575156211853]}
# {'sequence': '我同情别人的感受。', 'labels': ['精确', '准确', '错误', '失准', '普通'], 'scores': [0.23845688998699188, 0.22583413124084473, 0.18662138283252716, 0.18051597476005554, 0.1685716062784195]}
# {'sequence': '我对别人的问题不感兴趣。', 'labels': ['精确', '错误', '准确', '普通', '失准'], 'scores': [0.2330232858657837, 0.22931703925132751, 0.21901316940784454, 0.1952398121356964, 0.12340667098760605]}
# {'sequence': '我有一个柔软的心。', 'labels': ['错误', '准确', '精确', '普通', '失准'], 'scores': [0.359796404838562, 0.20450282096862793, 0.19809766113758087, 0.13629107177257538, 0.10131198912858963]}
# {'sequence': '我对别人并不感兴趣。', 'labels': ['精确', '错误', '普通', '准确', '失准'], 'scores': [0.22397997975349426, 0.22114534676074982, 0.21820108592510223, 0.20475666224956512, 0.13191694021224976]}
# {'sequence': '我抽出时间为别人。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.2928982377052307, 0.25478190183639526, 0.19005846977233887, 0.15465961396694183, 0.10760176181793213]}
# {'sequence': '我感觉到别人的情绪。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.25267350673675537, 0.23503026366233826, 0.18069250881671906, 0.1732521951198578, 0.1583515852689743]}
# {'sequence': '我让人们感到轻松。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.2735142111778259, 0.25421082973480225, 0.17551472783088684, 0.17391358315944672, 0.12284662574529648]}
# {'sequence': '我总是准备好。', 'labels': ['失准', '准确', '错误', '精确', '普通'], 'scores': [0.4984000027179718, 0.17650480568408966, 0.11884520202875137, 0.1173228919506073, 0.08892706036567688]}
# {'sequence': '我留下来。', 'labels': ['错误', '精确', '普通', '准确', '失准'], 'scores': [0.34336620569229126, 0.19749359786510468, 0.1951574981212616, 0.1697942465543747, 0.09418850392103195]}
# {'sequence': '我注意细节。', 'labels': ['准确', '精确', '错误', '失准', '普通'], 'scores': [0.3260842263698578, 0.24983181059360504, 0.14995358884334564, 0.14763475954532623, 0.12649567425251007]}
# {'sequence': '我弄乱了一团糟。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.2498784363269806, 0.1987667679786682, 0.1965898722410202, 0.1777634173631668, 0.17700155079364777]}
# {'sequence': '我马上完成了琐事。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.25830578804016113, 0.23415349423885345, 0.18474605679512024, 0.18298032879829407, 0.1398143172264099]}
# {'sequence': '我经常忘记将事情放回适当的位置。', 'labels': ['精确', '普通', '准确', '错误', '失准'], 'scores': [0.28100115060806274, 0.24609501659870148, 0.22214362025260925, 0.13093586266040802, 0.1198243647813797]}
# {'sequence': '我喜欢订单。', 'labels': ['普通', '精确', '准确', '错误', '失准'], 'scores': [0.23826666176319122, 0.23283517360687256, 0.23101265728473663, 0.18676479160785675, 0.11112066358327866]}
# {'sequence': '我逃脱了我的职责。', 'labels': ['普通', '精确', '准确', '错误', '失准'], 'scores': [0.26214635372161865, 0.23500917851924896, 0.21659590303897858, 0.1870952993631363, 0.09915325045585632]}
# {'sequence': '我遵循时间表。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.24926967918872833, 0.20023947954177856, 0.19690367579460144, 0.19184139370918274, 0.16174574196338654]}
# {'sequence': '我在工作中要严格。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.26443713903427124, 0.23010390996932983, 0.20148204267024994, 0.18505540490150452, 0.11892152577638626]}
# {'sequence': '我有一个丰富的词汇。', 'labels': ['准确', '精确', '错误', '普通', '失准'], 'scores': [0.252804160118103, 0.2372605800628662, 0.19860155880451202, 0.17116983234882355, 0.14016389846801758]}
# {'sequence': '我很难理解抽象思想。', 'labels': ['准确', '精确', '错误', '普通', '失准'], 'scores': [0.2855139672756195, 0.2684403359889984, 0.19086392223834991, 0.14415276050567627, 0.11102902144193649]}
# {'sequence': '我有生动的想象力。', 'labels': ['精确', '准确', '失准', '普通', '错误'], 'scores': [0.2831971049308777, 0.2376357764005661, 0.17329880595207214, 0.1573946624994278, 0.14847366511821747]}
# {'sequence': '我对抽象思想不感兴趣。', 'labels': ['准确', '精确', '错误', '普通', '失准'], 'scores': [0.2402779906988144, 0.22599543631076813, 0.2170877903699875, 0.20124296844005585, 0.11539587378501892]}
# {'sequence': '我有很好的想法。', 'labels': ['精确', '准确', '错误', '失准', '普通'], 'scores': [0.23362669348716736, 0.21596740186214447, 0.20189830660820007, 0.18658995628356934, 0.16191765666007996]}
# {'sequence': '我没有良好的想象力。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.2749115824699402, 0.23680484294891357, 0.16942746937274933, 0.16548052430152893, 0.1533755660057068]}
# {'sequence': '我很快了解事情。', 'labels': ['准确', '精确', '错误', '普通', '失准'], 'scores': [0.2647961676120758, 0.24763312935829163, 0.1887442022562027, 0.16366532444953918, 0.13516126573085785]}
# {'sequence': '我用困难的话。', 'labels': ['错误', '精确', '准确', '普通', '失准'], 'scores': [0.23534461855888367, 0.22814594209194183, 0.20537804067134857, 0.18782475590705872, 0.14330658316612244]}
# {'sequence': '我花时间思考事物。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.29846876859664917, 0.22623604536056519, 0.16608421504497528, 0.1582745760679245, 0.15093642473220825]}
# {'sequence': '我充满了想法。', 'labels': ['精确', '准确', '错误', '失准', '普通'], 'scores': [0.2749558091163635, 0.22516857087612152, 0.1741313338279724, 0.16382093727588654, 0.1619233340024948]}
# {'sequence': "Io sono l'anima della festa.", 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.677371084690094, 0.14922471344470978, 0.08846678584814072, 0.051066525280475616, 0.033870913088321686]}
# {'sequence': 'Non parlo molto.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.4942026436328888, 0.30513709783554077, 0.16867317259311676, 0.02226114645600319, 0.00972594041377306]}
# {'sequence': 'Mi sento a mio agio con le persone.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.46362486481666565, 0.3925119638442993, 0.11531570553779602, 0.01576431281864643, 0.012783169746398926]}
# {'sequence': 'Rimango sullo sfondo.', 'labels': [' In disaccordo', 'In accordo', ' Molto in accordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.3597238063812256, 0.3179149925708771, 0.12634167075157166, 0.10710042715072632, 0.08891913294792175]}
# {'sequence': 'Inizio le conversazioni.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.6219266057014465, 0.13401764631271362, 0.11248239874839783, 0.08284325152635574, 0.048730093985795975]}
# {'sequence': 'Ho poco da dire.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.6017105579376221, 0.22686037421226501, 0.07440639287233353, 0.0727928876876831, 0.024229710921645164]}
# {'sequence': 'Parlo con un sacco di persone diverse alle feste.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.5888798236846924, 0.19363808631896973, 0.07639278471469879, 0.07511197030544281, 0.06597732752561569]}
# {'sequence': "Non mi piace attirare l'attenzione su di me.", 'labels': [' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.5272915363311768, 0.38583746552467346, 0.06475873291492462, 0.016839785501360893, 0.005272530019283295]}
# {'sequence': "Non mi dispiace essere al centro dell'attenzione.", 'labels': [' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.6741030216217041, 0.2177702784538269, 0.09763132780790329, 0.006199430674314499, 0.004295891150832176]}
# {'sequence': 'Sono tranquillo con gli estranei.', 'labels': [' Molto in accordo', 'In accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.35962986946105957, 0.3062518537044525, 0.15828226506710052, 0.10984288901090622, 0.06599317491054535]}
# {'sequence': 'Mi stresso facilmente.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.39051419496536255, 0.3665671646595001, 0.1419609636068344, 0.05836958810687065, 0.04258808121085167]}
# {'sequence': 'Sono rilassato per la maggior parte del tempo.', 'labels': [' In disaccordo', ' Molto in accordo', 'In accordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.24532826244831085, 0.2147308886051178, 0.21106283366680145, 0.17101958394050598, 0.1578584462404251]}
# {'sequence': 'Mi preoccupo delle cose.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'In accordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo'], 'scores': [0.24197696149349213, 0.22446271777153015, 0.1985437273979187, 0.17904192209243774, 0.15597471594810486]}
# {'sequence': 'Raramente mi sento tristi.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.7035806179046631, 0.17606833577156067, 0.08140763640403748, 0.02061006985604763, 0.018333373591303825]}
# {'sequence': 'Mi disturbo facilmente.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', 'In accordo'], 'scores': [0.46464917063713074, 0.4641958773136139, 0.04849375784397125, 0.017418276518583298, 0.005242944695055485]}
# {'sequence': 'Mi arrabbio facilmente.', 'labels': ['In accordo', ' Molto in accordo', ' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.3925413191318512, 0.3041117191314697, 0.11935745179653168, 0.09591377526521683, 0.08807570487260818]}
# {'sequence': 'Cambio spesso il mio umore.', 'labels': [' In disaccordo', 'In accordo', 'Molto in disaccordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.30316290259361267, 0.28024256229400635, 0.18162468075752258, 0.17102733254432678, 0.06394252181053162]}
# {'sequence': "Ho frequenti sbalzi d'umore.", 'labels': ['Molto in disaccordo', ' In disaccordo', 'In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.31232866644859314, 0.2517797350883484, 0.15689899027347565, 0.14659668505191803, 0.1323959082365036]}
# {'sequence': 'Mi irrito facilmente.', 'labels': ['Molto in disaccordo', ' In disaccordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', 'In accordo'], 'scores': [0.44589534401893616, 0.4446953237056732, 0.050486139953136444, 0.03574097529053688, 0.02318226359784603]}
# {'sequence': 'Spesso mi sento tristi.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.678893506526947, 0.16066911816596985, 0.0880119651556015, 0.04500362649559975, 0.027421748265624046]}
# {'sequence': 'Provo poca preoccupazione per gli altri.', 'labels': [' In disaccordo', 'In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo'], 'scores': [0.29032376408576965, 0.2737939953804016, 0.1896095871925354, 0.13313798606395721, 0.1131347045302391]}
# {'sequence': 'Mi interessano le persone.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.41410091519355774, 0.3173123598098755, 0.1736505627632141, 0.06329357624053955, 0.03164259344339371]}
# {'sequence': 'Insulto le persone.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', 'In accordo'], 'scores': [0.7208367586135864, 0.2141423225402832, 0.05420000106096268, 0.005735883489251137, 0.005084857810288668]}
# {'sequence': 'Comprendo i sentimenti degli altri.', 'labels': ['In accordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.4352019727230072, 0.23288413882255554, 0.22621606290340424, 0.06254590302705765, 0.043151963502168655]}
# {'sequence': 'Non mi interessano i problemi degli altri.', 'labels': [' In disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', 'Molto in disaccordo', ' Molto in accordo'], 'scores': [0.4308544993400574, 0.2555394470691681, 0.13021358847618103, 0.09278540313243866, 0.09060704708099365]}
# {'sequence': 'Ho un cuore tenero.', 'labels': ['In accordo', ' In disaccordo', ' Molto in accordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.32510218024253845, 0.27743640542030334, 0.15813687443733215, 0.14529527723789215, 0.09402931481599808]}
# {'sequence': 'Non mi interessano molto gli altri.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.46005767583847046, 0.34046074748039246, 0.09666040539741516, 0.08046647161245346, 0.02235468477010727]}
# {'sequence': 'Mi prendo del tempo per gli altri.', 'labels': ['In accordo', ' Molto in accordo', ' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.4056045413017273, 0.24277161061763763, 0.180507630109787, 0.0882432758808136, 0.08287297189235687]}
# {'sequence': 'Sento le emozioni degli altri.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.4348304867744446, 0.1986566185951233, 0.18358628451824188, 0.10378198325634003, 0.07914461195468903]}
# {'sequence': 'Faccio sentire le persone a proprio agio.', 'labels': [' In disaccordo', 'In accordo', 'Molto in disaccordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.46197310090065, 0.2301628291606903, 0.10342042148113251, 0.10249493271112442, 0.10194867104291916]}
# {'sequence': 'Sono sempre preparato.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.47840097546577454, 0.2545042634010315, 0.17090816795825958, 0.060995008796453476, 0.035191603004932404]}
# {'sequence': 'Lascio le mie cose in giro.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.4502500295639038, 0.23473908007144928, 0.17281436920166016, 0.07870718091726303, 0.06348931789398193]}
# {'sequence': 'Presto attenzione ai dettagli.', 'labels': ['In accordo', ' In disaccordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo'], 'scores': [0.40165257453918457, 0.1922207623720169, 0.16550150513648987, 0.13191449642181396, 0.10871068388223648]}
# {'sequence': 'Faccio un casino di cose.', 'labels': [' In disaccordo', 'In accordo', 'Molto in disaccordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.3662227988243103, 0.25599294900894165, 0.14105293154716492, 0.11900191009044647, 0.11772942543029785]}
# {'sequence': 'Faccio subito le faccende domestiche.', 'labels': [' In disaccordo', 'In accordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo'], 'scores': [0.5596595406532288, 0.14714346826076508, 0.1309715211391449, 0.09509584307670593, 0.06712968647480011]}
# ...
# {'sequence': 'Non mi interessano molto gli altri.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.46005767583847046, 0.34046074748039246, 0.09666040539741516, 0.08046647161245346, 0.02235468477010727]}
# {'sequence': 'Mi prendo del tempo per gli altri.', 'labels': ['In accordo', ' Molto in accordo', ' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.4056045413017273, 0.24277161061763763, 0.180507630109787, 0.0882432758808136, 0.08287297189235687]}
# {'sequence': 'Sento le emozioni degli altri.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.4348304867744446, 0.1986566185951233, 0.18358628451824188, 0.10378198325634003, 0.07914461195468903]}
# {'sequence': 'Faccio sentire le persone a proprio agio.', 'labels': [' In disaccordo', 'In accordo', 'Molto in disaccordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.46197310090065, 0.2301628291606903, 0.10342042148113251, 0.10249493271112442, 0.10194867104291916]}
# {'sequence': 'Sono sempre preparato.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.47840097546577454, 0.2545042634010315, 0.17090816795825958, 0.060995008796453476, 0.035191603004932404]}
# {'sequence': 'Lascio le mie cose in giro.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.4502500295639038, 0.23473908007144928, 0.17281436920166016, 0.07870718091726303, 0.06348931789398193]}
# {'sequence': 'Faccio attenzione ai dettagli.', 'labels': ['In accordo', ' In disaccordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo'], 'scores': [0.3168657124042511, 0.26279619336128235, 0.14863064885139465, 0.14145396649837494, 0.13025350868701935]}
# {'sequence': 'Faccio un casino.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'In accordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo'], 'scores': [0.49103906750679016, 0.21310459077358246, 0.1677854061126709, 0.07232774049043655, 0.05574323982000351]}
# {'sequence': 'Faccio subito le faccende.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'In accordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo'], 'scores': [0.5185021758079529, 0.21373417973518372, 0.1100909635424614, 0.09125403314828873, 0.06641864776611328]}
# {'sequence': 'Spesso dimentico di rimettere le cose al loro posto.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.6116442680358887, 0.1724620759487152, 0.14258015155792236, 0.04464344680309296, 0.02867007628083229]}
# {'sequence': "Mi piace l'ordine.", 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.5663519501686096, 0.22223126888275146, 0.08704997599124908, 0.06902651488780975, 0.05534033477306366]}
# {'sequence': 'Mi sottraggo ai miei doveri.', 'labels': ['In accordo', ' In disaccordo', 'Molto in disaccordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo'], 'scores': [0.3411620855331421, 0.22759480774402618, 0.1596088707447052, 0.15922820568084717, 0.11240604519844055]}
# {'sequence': 'Seguo un programma.', 'labels': ['In accordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.5449979305267334, 0.18090280890464783, 0.17057792842388153, 0.05995415151119232, 0.043567147105932236]}
# {'sequence': 'Sono esigente nel mio lavoro.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.7916103601455688, 0.15437071025371552, 0.029940767213702202, 0.012812202796339989, 0.011265972629189491]}
# {'sequence': 'Ho un vocabolario ricco.', 'labels': [' Molto in accordo', 'In accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.3453029990196228, 0.2882749140262604, 0.13891752064228058, 0.13571108877658844, 0.0917934775352478]}
# {'sequence': 'Ho difficoltà a capire idee astratte.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.6942387819290161, 0.18288695812225342, 0.09824507683515549, 0.01701670140028, 0.007612493354827166]}
# {'sequence': 'Ho una fervida immaginazione.', 'labels': ['In accordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.32023683190345764, 0.2698386609554291, 0.19841726124286652, 0.12834495306015015, 0.08316227048635483]}
# {'sequence': 'Non mi interessano le idee astratte.', 'labels': [' In disaccordo', 'Molto in disaccordo', 'Nè in accordo nè in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.6911826133728027, 0.13982443511486053, 0.13549521565437317, 0.020823528990149498, 0.012674248777329922]}
# {'sequence': 'Ho delle idee eccellenti.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', ' In disaccordo', 'Molto in disaccordo'], 'scores': [0.5761193633079529, 0.29280856251716614, 0.07333791255950928, 0.02895730920135975, 0.028776854276657104]}
# {'sequence': 'Non ho una buona immaginazione.', 'labels': [' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.6805993318557739, 0.19148632884025574, 0.10120736807584763, 0.017744850367307663, 0.008962109684944153]}
# {'sequence': 'Sono veloce a capire le cose.', 'labels': ['In accordo', ' Molto in accordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', ' In disaccordo'], 'scores': [0.49812254309654236, 0.3604709506034851, 0.07002963125705719, 0.04032076150178909, 0.031056104227900505]}
# {'sequence': 'Io uso parole difficili.', 'labels': [' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo', 'In accordo', ' Molto in accordo'], 'scores': [0.6775769591331482, 0.13237062096595764, 0.12179525941610336, 0.04816969111561775, 0.020087426528334618]}
# {'sequence': 'Passo del tempo a riflettere sulle cose.', 'labels': [' In disaccordo', 'In accordo', 'Nè in accordo nè in disaccordo', ' Molto in accordo', 'Molto in disaccordo'], 'scores': [0.2546074390411377, 0.2534509003162384, 0.1668657511472702, 0.16643115878105164, 0.15864473581314087]}
# {'sequence': 'Sono pieno di idee.', 'labels': ['In accordo', ' Molto in accordo', ' In disaccordo', 'Nè in accordo nè in disaccordo', 'Molto in disaccordo'], 'scores': [0.40350744128227234, 0.250905305147171, 0.12902358174324036, 0.12462926656007767, 0.09193448722362518]}
# {'sequence': '我是党的生命。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.2278289943933487, 0.22406865656375885, 0.20670700073242188, 0.20503459870815277, 0.1363607794046402]}
# {'sequence': '我不怎么说话。', 'labels': ['错误', '普通', '准确', '精确', '失准'], 'scores': [0.2985305190086365, 0.19691400229930878, 0.18564648926258087, 0.18466275930404663, 0.13424624502658844]}
# {'sequence': '和人在一起我感觉很舒服。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.27474987506866455, 0.24869337677955627, 0.17546965181827545, 0.16985972225666046, 0.13122743368148804]}
# {'sequence': '我一直在幕后。', 'labels': ['精确', '准确', '普通', '失准', '错误'], 'scores': [0.25902891159057617, 0.23590075969696045, 0.17480023205280304, 0.16680598258972168, 0.16346414387226105]}
# {'sequence': '我开始交谈。', 'labels': ['精确', '错误', '准确', '普通', '失准'], 'scores': [0.2624152600765228, 0.22175800800323486, 0.21835465729236603, 0.1584450602531433, 0.13902704417705536]}
# {'sequence': '我没什么好说的。', 'labels': ['精确', '错误', '准确', '普通', '失准'], 'scores': [0.24535396695137024, 0.22909697890281677, 0.22479937970638275, 0.17209342122077942, 0.12865625321865082]}
# {'sequence': '我在聚会上和很多不同的人交谈。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.23486746847629547, 0.21551591157913208, 0.18998168408870697, 0.18554732203483582, 0.17408767342567444]}
# {'sequence': '我不喜欢引起别人的注意。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.22003605961799622, 0.21890752017498016, 0.2160995602607727, 0.19858507812023163, 0.1463717818260193]}
# {'sequence': '我不介意成为人们关注的焦点。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.24089182913303375, 0.21696940064430237, 0.20946763455867767, 0.19143949449062347, 0.14123158156871796]}
# {'sequence': '我在陌生人面前很安静。', 'labels': ['错误', '精确', '准确', '普通', '失准'], 'scores': [0.3194598853588104, 0.22631536424160004, 0.2056707739830017, 0.15010549128055573, 0.09844844788312912]}
# {'sequence': '我很容易感到压力过大。', 'labels': ['精确', '准确', '失准', '普通', '错误'], 'scores': [0.30533477663993835, 0.24268285930156708, 0.17278411984443665, 0.1498219221830368, 0.12937629222869873]}
# {'sequence': '我大部分时间都很放松。', 'labels': ['精确', '错误', '准确', '普通', '失准'], 'scores': [0.2512173056602478, 0.24123230576515198, 0.22029012441635132, 0.15891897678375244, 0.12834125757217407]}
# {'sequence': '我担心一些事情。', 'labels': ['准确', '精确', '普通', '错误', '失准'], 'scores': [0.2508939206600189, 0.2507513761520386, 0.18814849853515625, 0.17400439083576202, 0.13620176911354065]}
# {'sequence': '我很少感到忧郁。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.2649569809436798, 0.24137333035469055, 0.17978887259960175, 0.1755916029214859, 0.13828915357589722]}
# {'sequence': '我很容易被打扰。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.28033775091171265, 0.20454970002174377, 0.19786006212234497, 0.1727028340101242, 0.14454962313175201]}
# {'sequence': '我很容易生气。', 'labels': ['精确', '错误', '准确', '失准', '普通'], 'scores': [0.26821526885032654, 0.20842325687408447, 0.1824348121881485, 0.1723177582025528, 0.1686089187860489]}
# {'sequence': '我的心情变化很大。', 'labels': ['失准', '准确', '精确', '错误', '普通'], 'scores': [0.30900436639785767, 0.2119530588388443, 0.20413300395011902, 0.15030796825885773, 0.12460161000490189]}
# {'sequence': '我经常情绪波动。', 'labels': ['精确', '准确', '失准', '普通', '错误'], 'scores': [0.2967310845851898, 0.22602976858615875, 0.1665026992559433, 0.1635388731956482, 0.14719754457473755]}
# {'sequence': '我很容易生气。', 'labels': ['精确', '错误', '准确', '失准', '普通'], 'scores': [0.26821526885032654, 0.20842325687408447, 0.1824348121881485, 0.1723177582025528, 0.1686089187860489]}
# {'sequence': '我经常感到忧郁。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.293051540851593, 0.2475845217704773, 0.17603175342082977, 0.14554907381534576, 0.13778311014175415]}
# {'sequence': '我很少关心别人。', 'labels': ['精确', '普通', '准确', '错误', '失准'], 'scores': [0.27291131019592285, 0.19765448570251465, 0.19645388424396515, 0.16870346665382385, 0.1642768383026123]}
# {'sequence': '我对人很感兴趣。', 'labels': ['精确', '错误', '准确', '普通', '失准'], 'scores': [0.2722177803516388, 0.21575483679771423, 0.21474935114383698, 0.16566680371761322, 0.13161121308803558]}
# {'sequence': '我侮辱别人。', 'labels': ['精确', '准确', '普通', '失准', '错误'], 'scores': [0.2663433849811554, 0.24281498789787292, 0.19529825448989868, 0.15191268920898438, 0.14363063871860504]}
# {'sequence': '我同情别人的感受。', 'labels': ['精确', '准确', '错误', '失准', '普通'], 'scores': [0.23845688998699188, 0.22583413124084473, 0.18662138283252716, 0.18051597476005554, 0.1685716062784195]}
# {'sequence': '我对别人的问题不感兴趣。', 'labels': ['精确', '错误', '准确', '普通', '失准'], 'scores': [0.2330232858657837, 0.22931703925132751, 0.21901316940784454, 0.1952398121356964, 0.12340667098760605]}
# {'sequence': '我有一颗柔软的心。', 'labels': ['错误', '准确', '精确', '普通', '失准'], 'scores': [0.3880016803741455, 0.20349054038524628, 0.18007248640060425, 0.13538043200969696, 0.0930548906326294]}
# {'sequence': '我真的对别人不感兴趣。', 'labels': ['错误', '精确', '准确', '普通', '失准'], 'scores': [0.23094585537910461, 0.2147887647151947, 0.21304653584957123, 0.19857938587665558, 0.1426394134759903]}
# {'sequence': '我为别人抽出时间。', 'labels': ['精确', '准确', '普通', '失准', '错误'], 'scores': [0.2783869802951813, 0.25466224551200867, 0.1856105774641037, 0.14114335179328918, 0.14019687473773956]}
# {'sequence': '我能感受到别人的情绪。', 'labels': ['精确', '准确', '错误', '失准', '普通'], 'scores': [0.2402368038892746, 0.22675973176956177, 0.19447188079357147, 0.17063765227794647, 0.1678939312696457]}
# {'sequence': '我让人们感到自在。', 'labels': ['准确', '精确', '普通', '错误', '失准'], 'scores': [0.2813830077648163, 0.2646096646785736, 0.1819307804107666, 0.14603440463542938, 0.12604206800460815]}
# {'sequence': '我总是做好准备。', 'labels': ['失准', '准确', '精确', '错误', '普通'], 'scores': [0.3276677429676056, 0.21239890158176422, 0.16846874356269836, 0.1471090018749237, 0.1443556696176529]}
# {'sequence': '我把我的东西留在周围。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.23414860665798187, 0.22792889177799225, 0.19923655688762665, 0.18201397359371185, 0.15667188167572021]}
# {'sequence': '我注重细节。', 'labels': ['准确', '精确', '失准', '错误', '普通'], 'scores': [0.3262571096420288, 0.25550758838653564, 0.14773991703987122, 0.1372765600681305, 0.13321882486343384]}
# {'sequence': '我把事情搞得一团糟。', 'labels': ['精确', '准确', '普通', '失准', '错误'], 'scores': [0.2940465807914734, 0.24167539179325104, 0.16757944226264954, 0.1632729023694992, 0.13342566788196564]}
# {'sequence': '我马上就把家务活做完。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.2767239809036255, 0.23514461517333984, 0.19006580114364624, 0.16101184487342834, 0.1370537281036377]}
# {'sequence': '我经常忘记把东西放回原处。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.28401657938957214, 0.25068798661231995, 0.17371007800102234, 0.1528056412935257, 0.13877977430820465]}
# {'sequence': '我喜欢点菜。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.264778733253479, 0.2307857722043991, 0.22008509933948517, 0.19089245796203613, 0.09345798939466476]}
# {'sequence': '我逃避我的职责。', 'labels': ['普通', '精确', '准确', '错误', '失准'], 'scores': [0.29681703448295593, 0.22165808081626892, 0.19761596620082855, 0.1889205127954483, 0.09498843550682068]}
# {'sequence': '我遵守时间表。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.25196778774261475, 0.21621908247470856, 0.20153312385082245, 0.18631479144096375, 0.14396516978740692]}
# {'sequence': '我工作要求很高。', 'labels': ['精确', '准确', '失准', '普通', '错误'], 'scores': [0.2668267786502838, 0.2230452299118042, 0.18682830035686493, 0.16587378084659576, 0.1574259251356125]}
# {'sequence': '我的词汇量很丰富。', 'labels': ['准确', '精确', '失准', '普通', '错误'], 'scores': [0.25862982869148254, 0.2406962811946869, 0.17361308634281158, 0.17023272812366486, 0.1568281352519989]}
# {'sequence': '我很难理解抽象的想法。', 'labels': ['准确', '精确', '错误', '普通', '失准'], 'scores': [0.26843708753585815, 0.2681215703487396, 0.18411321938037872, 0.15058672428131104, 0.12874141335487366]}
# {'sequence': '我有着生动的想象力。', 'labels': ['精确', '准确', '失准', '错误', '普通'], 'scores': [0.2843136787414551, 0.2478506863117218, 0.1594005972146988, 0.15752233564853668, 0.15091268718242645]}
# {'sequence': '我对抽象思想不感兴趣。', 'labels': ['准确', '精确', '错误', '普通', '失准'], 'scores': [0.2402779906988144, 0.22599543631076813, 0.2170877903699875, 0.20124296844005585, 0.11539587378501892]}
# {'sequence': '我有很好的想法。', 'labels': ['精确', '准确', '错误', '失准', '普通'], 'scores': [0.23362669348716736, 0.21596740186214447, 0.20189830660820007, 0.18658995628356934, 0.16191765666007996]}
# {'sequence': '我没有很好的想象力。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.26911866664886475, 0.22934989631175995, 0.16971902549266815, 0.16901272535324097, 0.1627996414899826]}
# {'sequence': '我很快就能理解事情。', 'labels': ['准确', '精确', '失准', '错误', '普通'], 'scores': [0.26500341296195984, 0.24180032312870026, 0.1856449991464615, 0.16821280121803284, 0.13933847844600677]}
# {'sequence': '我用难单词。', 'labels': ['精确', '准确', '错误', '普通', '失准'], 'scores': [0.2371993213891983, 0.23145164549350739, 0.21471388638019562, 0.19330424070358276, 0.12333095818758011]}
# {'sequence': '我花时间思考事情。', 'labels': ['精确', '准确', '普通', '错误', '失准'], 'scores': [0.2787952125072479, 0.23445935547351837, 0.16713936626911163, 0.16345511376857758, 0.15615101158618927]}
# {'sequence': '我有很多想法。', 'labels': ['精确', '失准', '准确', '错误', '普通'], 'scores': [0.21800512075424194, 0.21763478219509125, 0.21224787831306458, 0.17808999121189117, 0.17402221262454987]}

# %%
# Change all language labels to english

answers_all_english = pd.DataFrame(columns=candidate_labels_en)
answers_all_english["language"] = []
answers_all_english["model"] = []
answers_all_english["item"] = []
answers_all_english["item_index"] = []

for lan in range(0, len(languages)):
    # extract responses for different languages
    answers_temp = pd.DataFrame(
        [
            dict(zip(x["labels"], x["scores"]))
            for x in responses[lan * 50 : lan * 50 + 50]
        ]
    )
    # insert language
    answers_temp.insert(len(answers_temp.columns), "language", big5_qs.columns[lan+1])
    # insert model name
    answers_temp["model"] = list(np.repeat('model', 50))
    # insert item text
    answers_temp.insert(len(answers_temp.columns), "item", big5_qs["question"])
    answers_temp.insert(
        len(answers_temp.columns), "item_index", list(range(1, len(questionlist) + 1))
    )
    # adjust column names
    answers_temp = answers_temp.rename(
        columns=dict(zip(labels[languages[lan]], labels["en"]))
    )
    # concatenate
    answers_all_english = pd.concat([answers_all_english, answers_temp])

answers_all_english
# Out:
#     Very Inaccurate  Moderately Inaccurate  Neither Accurate Nor Inaccurate  \
# 0          0.030613               0.183896                         0.064634
# 1          0.046128               0.294150                         0.022331
# 2          0.026726               0.210313                         0.034622
# 3          0.040123               0.281780                         0.037826
# 4          0.044577               0.253531                         0.043915
# ..              ...                    ...                              ...
# 45         0.169719               0.162800                         0.169013
# 46         0.168213               0.185645                         0.139338
# 47         0.214714               0.123331                         0.193304
# 48         0.163455               0.156151                         0.167139
# 49         0.178090               0.217635                         0.174022
#
#     Moderately Accurate  Very Accurate  language  model  \
# 0              0.403802       0.317055  question  model
# 1              0.601645       0.035745  question  model
# 2              0.605224       0.123115  question  model
# 3              0.588398       0.051873  question  model
# 4              0.538469       0.119508  question  model
# ..                  ...            ...       ...    ...
# 45             0.229350       0.269119  zh_baidu  model
# 46             0.265003       0.241800  zh_baidu  model
# 47             0.231452       0.237199  zh_baidu  model
# 48             0.234459       0.278795  zh_baidu  model
# 49             0.212248       0.218005  zh_baidu  model
#
#                                   item  item_index
# 0          I am the life of the party.         1.0
# 1                  I don't talk a lot.         2.0
# 2    I feel comfortable around people.         3.0
# 3            I keep in the background.         4.0
# 4               I start conversations.         5.0
# ..                                 ...         ...
# 45   I do not have a good imagination.        46.0
# 46    I am quick to understand things.        47.0
# 47              I use difficult words.        48.0
# 48  I spend time reflecting on things.        49.0
# 49                 I am full of ideas.        50.0
#
# [350 rows x 9 columns]

# %% [markdown]
# ### Prepare Data set for Scoring
# Specifically, we want to have item as columns, and, for each of the response options, we want to calculate the argmax (i.e., the category with the highest probability

# %%
df = answers_all_english

# Selecting the scoring columns
score_columns = [
    "Very Inaccurate",
    "Moderately Inaccurate",
    "Neither Accurate Nor Inaccurate",
    "Moderately Accurate",
    "Very Accurate",
]

# Finding the column with the highest score for each row
df["max_score"] = df[score_columns].idxmax(axis=1)

# Mapping column names to numeric scores
column_to_score = {
    "Very Inaccurate": 1,
    "Moderately Inaccurate": 2,
    "Neither Accurate Nor Inaccurate": 3,
    "Moderately Accurate": 4,
    "Very Accurate": 5,
}

df["score"] = df["max_score"].map(column_to_score)

# Pivoting the DataFrame
transformed_df = df.pivot_table(
    index=["language", "model"], columns="item", values="score", aggfunc="first"
)

# Resetting the index
transformed_df.reset_index(inplace=True)

# Display the transformed DataFrame
transformed_df
# Out:
# item   language  model  I am always prepared.  I am easily disturbed.  \
# 0      it_baidu  model                      4                       2
# 1       it_bing  model                      4                       2
# 2     it_google  model                      4                       2
# 3      question  model                      4                       2
# 4      zh_baidu  model                      2                       5
# 5       zh_bing  model                      2                       5
# 6     zh_google  model                      2                       5
#
# item  I am exacting in my work.  I am full of ideas.  \
# 0                             4                    4
# 1                             4                    4
# 2                             4                    4
# 3                             5                    4
# 4                             5                    5
# 5                             5                    5
# 6                             5                    5
#
# item  I am interested in people.  I am not interested in abstract ideas.  \
# 0                              4                                       2
# 1                              4                                       2
# 2                              4                                       2
# 3                              4                                       4
# 4                              5                                       4
# 5                              5                                       4
# 6                              5                                       4
#
# item  I am not interested in other people's problems.  \
# 0                                                   2
# 1                                                   2
# 2                                                   2
# 3                                                   4
# 4                                                   5
# 5                                                   5
# 6                                                   5
#
# item  I am not really interested in others.  ...  I pay attention to details.  \
# 0                                         2  ...                            4
# 1                                         2  ...                            4
# 2                                         2  ...                            4
# 3                                         4  ...                            4
# 4                                         1  ...                            4
# 5                                         5  ...                            4
# 6                                         5  ...                            4
#
# item  I seldom feel blue.  I shirk my duties.  \
# 0                       2                   4
# 1                       2                   4
# 2                       2                   4
# 3                       4                   2
# 4                       5                   3
# 5                       5                   5
# 6                       5                   3
#
# item  I spend time reflecting on things.  I start conversations.  \
# 0                                      2                       4
# 1                                      2                       4
# 2                                      2                       4
# 3                                      4                       4
# 4                                      5                       5
# 5                                      5                       1
# 6                                      5                       1
#
# item  I sympathize with others' feelings.  I take time out for others.  \
# 0                                       4                            4
# 1                                       4                            4
# 2                                       4                            4
# 3                                       4                            4
# 4                                       5                            5
# 5                                       5                            5
# 6                                       5                            5
#
# item  I talk to a lot of different people at parties.  I use difficult words.  \
# 0                                                   1                       2
# 1                                                   4                       2
# 2                                                   1                       2
# 3                                                   4                       2
# 4                                                   5                       5
# 5                                                   5                       4
# 6                                                   5                       1
#
# item  I worry about things.
# 0                         2
# 1                         2
# 2                         2
# 3                         4
# 4                         4
# 5                         5
# 6                         5
#
# [7 rows x 52 columns]

# %%
transformed_df.columns
# Out:
# Index(['language', 'model', 'I am always prepared.', 'I am easily disturbed.',
#        'I am exacting in my work.', 'I am full of ideas.',
#        'I am interested in people.', 'I am not interested in abstract ideas.',
#        'I am not interested in other people's problems.',
#        'I am not really interested in others.',
#        'I am quick to understand things.', 'I am quiet around strangers.',
#        'I am relaxed most of the time.', 'I am the life of the party.',
#        'I change my mood a lot.', 'I do not have a good imagination.',
#        'I don't like to draw attention to myself.',
#        'I don't mind being the center of attention.', 'I don't talk a lot.',
#        'I feel comfortable around people.',
#        'I feel little concern for others.', 'I feel others' emotions.',
#        'I follow a schedule.', 'I get chores done right away.',
#        'I get irritated easily.', 'I get stressed out easily.',
#        'I get upset easily.', 'I have a rich vocabulary.',
#        'I have a soft heart.', 'I have a vivid imagination.',
#        'I have difficulty understanding abstract ideas.',
#        'I have excellent ideas.', 'I have frequent mood swings.',
#        'I have little to say.', 'I insult people.',
#        'I keep in the background.', 'I leave my belongings around.',
#        'I like order.', 'I make a mess of things.',
#        'I make people feel at ease.', 'I often feel blue.',
#        'I often forget to put things back in their proper place.',
#        'I pay attention to details.', 'I seldom feel blue.',
#        'I shirk my duties.', 'I spend time reflecting on things.',
#        'I start conversations.', 'I sympathize with others' feelings.',
#        'I take time out for others.',
#        'I talk to a lot of different people at parties.',
#        'I use difficult words.', 'I worry about things.'],
#       dtype='object', name='item')

# %% [markdown]
# ## Step 3: Collect empirical data for each of the languages that were used by the llm model

# %%
kag_b5 = pd.read_csv('data-final.csv', sep="\t")

# %%
import copy 
#collect different data sets for each of the countries
kag_b5_us = kag_b5[kag_b5['country'] == 'US']
kag_b5_it = kag_b5[kag_b5['country'] == 'IT']
kag_b5_ch = kag_b5[kag_b5['country'] == 'CN']

# %%
kag_b5_it = kag_b5_it[:50].rename(columns = dict(zip(big5_qs['item'], big5_qs['question'])))
kag_b5_it.iloc[:,:50].describe()
# Out:
#        I am the life of the party.  I don't talk a lot.  \
# count                    50.000000             50.00000
# mean                      2.420000              2.84000
# std                       1.213697              1.44787
# min                       0.000000              0.00000
# 25%                       1.000000              2.00000
# 50%                       3.000000              3.00000
# 75%                       3.000000              4.00000
# max                       5.000000              5.00000
#
#        I feel comfortable around people.  I keep in the background.  \
# count                          50.000000                  50.000000
# mean                            2.960000                   3.240000
# std                             1.384462                   1.363669
# min                             0.000000                   0.000000
# 25%                             2.000000                   2.000000
# 50%                             3.000000                   3.000000
# 75%                             4.000000                   4.000000
# max                             5.000000                   5.000000
#
#        I start conversations.  I have little to say.  \
# count               50.000000              50.000000
# mean                 2.900000               2.520000
# std                  1.403349               1.265556
# min                  0.000000               0.000000
# 25%                  2.000000               2.000000
# 50%                  3.000000               2.000000
# 75%                  4.000000               3.000000
# max                  5.000000               5.000000
#
#        I talk to a lot of different people at parties.  \
# count                                        50.000000
# mean                                          2.460000
# std                                           1.487499
# min                                           0.000000
# 25%                                           1.000000
# 50%                                           2.000000
# 75%                                           4.000000
# max                                           5.000000
#
#        I don't like to draw attention to myself.  \
# count                                   50.00000
# mean                                     3.46000
# std                                      1.35842
# min                                      0.00000
# 25%                                      3.00000
# 50%                                      4.00000
# 75%                                      5.00000
# max                                      5.00000
#
#        I don't mind being the center of attention.  \
# count                                    50.000000
# mean                                      2.800000
# std                                       1.355262
# min                                       0.000000
# 25%                                       2.000000
# 50%                                       3.000000
# 75%                                       4.000000
# max                                       5.000000
#
#        I am quiet around strangers.  ...  I have a rich vocabulary.  \
# count                     50.000000  ...                  50.000000
# mean                       3.720000  ...                   3.900000
# std                        1.229568  ...                   1.147313
# min                        0.000000  ...                   0.000000
# 25%                        3.000000  ...                   3.000000
# 50%                        4.000000  ...                   4.000000
# 75%                        5.000000  ...                   5.000000
# max                        5.000000  ...                   5.000000
#
#        I have difficulty understanding abstract ideas.  \
# count                                        50.000000
# mean                                          1.680000
# std                                           0.793854
# min                                           0.000000
# 25%                                           1.000000
# 50%                                           2.000000
# 75%                                           2.000000
# max                                           4.000000
#
#        I have a vivid imagination.  I am not interested in abstract ideas.  \
# count                    50.000000                                50.00000
# mean                      4.080000                                 1.88000
# std                       1.175255                                 1.06215
# min                       0.000000                                 0.00000
# 25%                       4.000000                                 1.00000
# 50%                       4.000000                                 2.00000
# 75%                       5.000000                                 2.75000
# max                       5.000000                                 5.00000
#
#        I have excellent ideas.  I do not have a good imagination.  \
# count                50.000000                          50.000000
# mean                  3.680000                           1.720000
# std                   1.077412                           1.050559
# min                   0.000000                           0.000000
# 25%                   3.000000                           1.000000
# 50%                   4.000000                           1.000000
# 75%                   4.000000                           2.000000
# max                   5.000000                           5.000000
#
#        I am quick to understand things.  I use difficult words.  \
# count                         50.000000               50.000000
# mean                           3.760000                3.300000
# std                            1.270706                1.111168
# min                            0.000000                0.000000
# 25%                            3.000000                2.250000
# 50%                            4.000000                4.000000
# 75%                            5.000000                4.000000
# max                            5.000000                5.000000
#
#        I spend time reflecting on things.  I am full of ideas.
# count                           50.000000            50.000000
# mean                             4.340000             3.940000
# std                              0.981669             1.114103
# min                              0.000000             0.000000
# 25%                              4.000000             3.000000
# 50%                              5.000000             4.000000
# 75%                              5.000000             5.000000
# max                              5.000000             5.000000
#
# [8 rows x 50 columns]

# %%
transformed_df[list(kag_b5_us.columns[:50])]
# Out:
# item  I am the life of the party.  I don't talk a lot.  \
# 0                               4                    2
# 1                               4                    2
# 2                               4                    2
# 3                               4                    4
# 4                               5                    1
# 5                               5                    1
# 6                               5                    1
#
# item  I feel comfortable around people.  I keep in the background.  \
# 0                                     4                          4
# 1                                     4                          2
# 2                                     4                          2
# 3                                     4                          4
# 4                                     5                          5
# 5                                     4                          5
# 6                                     1                          1
#
# item  I start conversations.  I have little to say.  \
# 0                          4                      2
# 1                          4                      2
# 2                          4                      2
# 3                          4                      2
# 4                          5                      5
# 5                          1                      5
# 6                          1                      1
#
# item  I talk to a lot of different people at parties.  \
# 0                                                   1
# 1                                                   4
# 2                                                   1
# 3                                                   4
# 4                                                   5
# 5                                                   5
# 6                                                   5
#
# item  I don't like to draw attention to myself.  \
# 0                                             2
# 1                                             2
# 2                                             2
# 3                                             4
# 4                                             5
# 5                                             5
# 6                                             4
#
# item  I don't mind being the center of attention.  \
# 0                                               2
# 1                                               2
# 2                                               2
# 3                                               4
# 4                                               5
# 5                                               5
# 6                                               5
#
# item  I am quiet around strangers.  ...  I have a rich vocabulary.  \
# 0                                2  ...                          5
# 1                                5  ...                          5
# 2                                5  ...                          5
# 3                                4  ...                          4
# 4                                1  ...                          4
# 5                                1  ...                          4
# 6                                1  ...                          4
#
# item  I have difficulty understanding abstract ideas.  \
# 0                                                   2
# 1                                                   2
# 2                                                   2
# 3                                                   2
# 4                                                   4
# 5                                                   4
# 6                                                   4
#
# item  I have a vivid imagination.  I am not interested in abstract ideas.  \
# 0                               4                                       2
# 1                               4                                       2
# 2                               4                                       2
# 3                               2                                       4
# 4                               5                                       4
# 5                               5                                       4
# 6                               5                                       4
#
# item  I have excellent ideas.  I do not have a good imagination.  \
# 0                           4                                  2
# 1                           4                                  2
# 2                           4                                  2
# 3                           5                                  2
# 4                           5                                  5
# 5                           5                                  5
# 6                           5                                  5
#
# item  I am quick to understand things.  I use difficult words.  \
# 0                                    4                       2
# 1                                    4                       2
# 2                                    2                       2
# 3                                    4                       2
# 4                                    4                       5
# 5                                    5                       4
# 6                                    4                       1
#
# item  I spend time reflecting on things.  I am full of ideas.
# 0                                      2                    4
# 1                                      2                    4
# 2                                      2                    4
# 3                                      4                    4
# 4                                      5                    5
# 5                                      5                    5
# 6                                      5                    5
#
# [7 rows x 50 columns]
